# %% [markdown]
# # Imports

# %%
# %matplotlib inline

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import sys
import tensorflow as tf
from tensorflow import keras
import time

# %%
import importlib
import helper.series

# %%
importlib.reload(helper.series)
# Out:
# <module 'helper.series' from '/home/jupyter/multitarget/helper/series.py'>

# %%
print("python", sys.version)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# python 3.5.3 (default, Sep 27 2018, 17:25:39)
# [GCC 6.3.0 20170516]
# matplotlib 3.0.3
# numpy 1.18.1
# pandas 0.25.3
# sklearn 0.19.2
# tensorflow 2.1.0
# tensorflow_core.python.keras.api._v2.keras 2.2.4-tf

# %%
assert sys.version_info >= (3, 5) # Python ≥3.5 required
assert tf.__version__ >= "2.0"    # TensorFlow ≥2.0 required

# %% [markdown]
# # Dataset Builder

# %%
def timeseries_dataset(series, window_size, shift, batchsize, targetsize):
    """
    From the original timeseries it generates the inputs for the network, and the labels.
    The labels lenght will be the target lenght of the forecast.
    Parameters:
      series: the input time series
      window_size: the lenght of the input
      shift: window shift along the series
      batchsize: batchsize
      targetsize: the size of the forecasted length
    Output: dataset of the input and label batches
    """
    ds = tf.data.Dataset.from_tensor_slices(series)
    stype = ds.element_spec.dtype
    ds = ds.window(window_size + targetsize, shift=shift, drop_remainder=True)
    ds = ds.flat_map(lambda window: window.batch(window_size + targetsize))
    if targetsize > 1:
        ds = ds.map(lambda window: (window[:-targetsize, np.newaxis], tf.map_fn(lambda i: window[i+1:i+1+targetsize], tf.range(window_size), dtype=stype)))
    elif targetsize == 1:
        ds = ds.map(lambda window: (window[:-targetsize, np.newaxis], window[targetsize:, np.newaxis]))
    elif targetsize == 0:
        ds = ds.map(lambda window: (window[:, np.newaxis], window[:, np.newaxis]))          
    return ds.batch(batchsize, drop_remainder=True)

# %% [markdown]
# # Build Time Series

# %%
time = np.arange(8 * 365)
builder = helper.series.SeriesBuilder(baseline=10, slope=0.05, period=365, amplitude=50, noise_level=5)
t_series = builder.generate_series(time)

# %%
helper.series.plot_series(time, t_series)

# %%
# check output of the function
ds_demo = timeseries_dataset(time, window_size=3, shift=1, batchsize=2, targetsize=2)
next(iter(ds_demo))
# Out:
# (<tf.Tensor: shape=(2, 3, 1), dtype=int64, numpy=
#  array([[[0],
#          [1],
#          [2]],
#
#         [[1],
#          [2],
#          [3]]])>, <tf.Tensor: shape=(2, 3, 2), dtype=int64, numpy=
#  array([[[1, 2],
#          [2, 3],
#          [3, 4]],
#
#         [[2, 3],
#          [3, 4],
#          [4, 5]]])>)

# %%
# split the time and timeseries to train and validation set
time_train = time[:365*6]
x_train = t_series[:365*6]
time_valid = time[365*6:365*7]
x_valid = t_series[365*6:365*7]
time_test = time[365*7:]
x_test = t_series[365*7:]

# %%
# build the training / validation dataset for the 1 and more target size
train_set_1 = timeseries_dataset(x_train, window_size=30, shift=1, batchsize=16, targetsize=1)
valid_set_1 = timeseries_dataset(x_valid, window_size=30, shift=1, batchsize=16, targetsize=1)
test_set_1 = timeseries_dataset(x_test, window_size=30, shift=1, batchsize=16, targetsize=1)

train_set_5 = timeseries_dataset(x_train, window_size=30, shift=1, batchsize=16, targetsize=5)
valid_set_5 = timeseries_dataset(x_valid, window_size=30, shift=1, batchsize=16, targetsize=5)
test_set_5 = timeseries_dataset(x_test, window_size=30, shift=1, batchsize=16, targetsize=5)

# %% [markdown]
# # Network Layouts and Trainers

# %%
def simple_lstm_layout(batchsize, targetsize):  
    """
    Define a simple LSTM layout
    """
    keras.backend.clear_session()
    tf.random.set_seed(42)
    np.random.seed(42)

    # model layout
    model = keras.models.Sequential([
    keras.layers.LSTM(100, 
                      return_sequences=True,
                      batch_input_shape=[batchsize, None, 1]),
    keras.layers.LSTM(100, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(targetsize)),
    keras.layers.Lambda(lambda x: x * 200.0) # scale the outputs for faster learning
    ])
    return model

# %%
def learning_rate_finder(model, train_set):  
    """
    Goes trough learning rates and gives back the history object
    to find optimal learning rate.
    """
    # check learning rates to find the best
    lr_schedule = keras.callbacks.LearningRateScheduler(
      lambda epoch: 1e-8 * 10**(epoch / 20))
    optimizer = keras.optimizers.SGD(lr=1e-8, momentum=0.9)
    model.compile(loss=keras.losses.Huber(),
                optimizer=optimizer,
                metrics=["mae"])
    # get history to find the best learning rate
    return model.fit(train_set, epochs=10, callbacks=[lr_schedule]) # ep 100

# %%
def model_trainer(model, lr, train_set, valid_set, checkpoint_name):
    """
    Builds simple lstm network.
    Returns the history object
    """
    keras.backend.clear_session()
    tf.random.set_seed(42)
    np.random.seed(42)
    optimizer = keras.optimizers.SGD(lr=lr, momentum=0.9) # use best learning rate estimation
    model.compile(loss=keras.losses.Huber(),
                optimizer=optimizer,
                metrics=["mae"])
    model_checkpoint = keras.callbacks.ModelCheckpoint(
      checkpoint_name, save_best_only=True)
    early_stopping = keras.callbacks.EarlyStopping(patience=50)
    return model.fit(train_set, epochs=10, # ep 1000
            validation_data=valid_set,
            callbacks=[early_stopping, model_checkpoint])

# %% [markdown]
# # Test LSTM with target size 1

# %%
model_lstm_ts1 = simple_lstm_layout(batchsize=16, targetsize=1)

# %%
helper.series.lr_loss_chart(learning_rate_finder(model_lstm_ts1, train_set=train_set_1), 1e-8, 1e-4, 0, 30)
# Out:
# Epoch 1/10
# 135/135 [==============================] - 14s 103ms/step - loss: 78.8117 - mae: 79.3116
# Epoch 2/10
# 135/135 [==============================] - 10s 71ms/step - loss: 45.1230 - mae: 45.6228
# Epoch 3/10
# 135/135 [==============================] - 9s 69ms/step - loss: 19.9208 - mae: 20.4131
# Epoch 4/10
# 135/135 [==============================] - 10s 70ms/step - loss: 18.6927 - mae: 19.1875
# Epoch 5/10
# 135/135 [==============================] - 10s 71ms/step - loss: 18.0083 - mae: 18.5022
# Epoch 6/10
# 135/135 [==============================] - 9s 69ms/step - loss: 16.9704 - mae: 17.4635
# Epoch 7/10
# 135/135 [==============================] - 9s 70ms/step - loss: 14.9102 - mae: 15.4006
# Epoch 8/10
# 135/135 [==============================] - 9s 70ms/step - loss: 14.8079 - mae: 15.2986
# Epoch 9/10
# 135/135 [==============================] - 9s 69ms/step - loss: 14.7182 - mae: 15.2090
# Epoch 10/10
# 135/135 [==============================] - 9s 69ms/step - loss: 14.3002 - mae: 14.7908

# %%
# we see that lr around 5e-7 can be good, so train the network with that
history_lstm_1 = model_trainer(model_lstm_ts1, lr = 5e-7, train_set = train_set_1, valid_set = valid_set_1, checkpoint_name = "cp_lstm_1.h5")
# Out:
# Epoch 1/10
# 135/135 [==============================] - 15s 110ms/step - loss: 13.1653 - mae: 13.6543 - val_loss: 20.0420 - val_mae: 20.5392
# Epoch 2/10
# 135/135 [==============================] - 9s 67ms/step - loss: 11.9138 - mae: 12.4025 - val_loss: 18.2012 - val_mae: 18.6957
# Epoch 3/10
# 135/135 [==============================] - 9s 67ms/step - loss: 10.7459 - mae: 11.2339 - val_loss: 17.1813 - val_mae: 17.6732
# Epoch 4/10
# 135/135 [==============================] - 9s 66ms/step - loss: 9.6260 - mae: 10.1119 - val_loss: 15.9642 - val_mae: 16.4556
# Epoch 5/10
# 135/135 [==============================] - 9s 67ms/step - loss: 8.8109 - mae: 9.2955 - val_loss: 14.9674 - val_mae: 15.4595
# Epoch 6/10
# 135/135 [==============================] - 9s 67ms/step - loss: 8.5713 - mae: 9.0561 - val_loss: 14.4289 - val_mae: 14.9200
# Epoch 7/10
# 135/135 [==============================] - 9s 66ms/step - loss: 8.2871 - mae: 8.7715 - val_loss: 14.0526 - val_mae: 14.5439
# Epoch 8/10
# 135/135 [==============================] - 9s 67ms/step - loss: 8.0522 - mae: 8.5357 - val_loss: 13.8003 - val_mae: 14.2919
# Epoch 9/10
# 135/135 [==============================] - 9s 67ms/step - loss: 7.8384 - mae: 8.3209 - val_loss: 13.5914 - val_mae: 14.0829
# Epoch 10/10
# 135/135 [==============================] - 9s 66ms/step - loss: 7.6582 - mae: 8.1403 - val_loss: 13.3932 - val_mae: 13.8843

# %%
model_lstm_ts1 = keras.models.load_model("cp_lstm_1.h5")

# %%
rnn_forecast = model_lstm_ts1.predict(test_set_1)
print(rnn_forecast.shape)
# in every step we only need the last output of the "return sequence"
rnn_forecast = np.squeeze(rnn_forecast[:, -1, 0])
print(rnn_forecast.shape)

plt.plot(rnn_forecast)
# Out:
# (320, 30, 1)
# (320,)

# %%
plt.figure(figsize=(10, 6))
helper.series.plot_series(time_test, x_test)
helper.series.plot_series(time_test[31:-14], rnn_forecast)
helper.series.plot_series(time_test[31:-14], x_test[31:-14] - rnn_forecast)

# %%
keras.metrics.mean_absolute_error(x_test[31:-14], rnn_forecast).numpy()
# Out:
# 16.640207

# %% [markdown]
# # Test LSTM with target size 5

# %%
model_lstm_ts5 = simple_lstm_layout(batchsize=16, targetsize=5)

# %%
helper.series.lr_loss_chart(learning_rate_finder(model_lstm_ts5, train_set=train_set_5), 1e-8, 1e-4, 0, 80)

# %%
# we see that lr around 5e-7 can be good, so train the network with that
history_lstm_5 = model_trainer(model_lstm_ts5, lr = 5e-7, train_set = train_set_5, valid_set = valid_set_5, checkpoint_name = "cp_lstm_5.h5")
# Out:
# Epoch 1/10
# 134/134 [==============================] - 17s 127ms/step - loss: 26.4265 - mae: 26.9215 - val_loss: 33.5050 - val_mae: 34.0033
# Epoch 2/10
# 134/134 [==============================] - 12s 87ms/step - loss: 27.0089 - mae: 27.5030 - val_loss: 31.5254 - val_mae: 32.0241
# Epoch 3/10
# 134/134 [==============================] - 12s 86ms/step - loss: 23.4476 - mae: 23.9406 - val_loss: 30.6564 - val_mae: 31.1551
# Epoch 4/10
# 134/134 [==============================] - 11s 86ms/step - loss: 20.6138 - mae: 21.1052 - val_loss: 29.4560 - val_mae: 29.9546
# Epoch 5/10
# 134/134 [==============================] - 11s 84ms/step - loss: 18.0841 - mae: 18.5744 - val_loss: 28.1782 - val_mae: 28.6766
# Epoch 6/10
# 134/134 [==============================] - 11s 86ms/step - loss: 16.3260 - mae: 16.8157 - val_loss: 26.8199 - val_mae: 27.3182
# Epoch 7/10
# 134/134 [==============================] - 12s 86ms/step - loss: 15.1024 - mae: 15.5916 - val_loss: 25.6129 - val_mae: 26.1110
# Epoch 8/10
# 134/134 [==============================] - 12s 86ms/step - loss: 14.0734 - mae: 14.5622 - val_loss: 24.4969 - val_mae: 24.9945
# Epoch 9/10
# 134/134 [==============================] - 12s 87ms/step - loss: 13.3396 - mae: 13.8277 - val_loss: 23.4986 - val_mae: 23.9956
# Epoch 10/10
# 134/134 [==============================] - 12s 87ms/step - loss: 12.7979 - mae: 13.2855 - val_loss: 22.5985 - val_mae: 23.0948

# %%
model_lstm_ts5 = keras.models.load_model("cp_lstm_5.h5")

# %%
rnn_forecast = model_lstm_ts5.predict(test_set_5)
print(rnn_forecast.shape)
# in every step we only need the last output of the "return sequence"
rnn_forecast = np.squeeze(rnn_forecast[:, -1, 0])
print(rnn_forecast.shape)

plt.plot(rnn_forecast)
# Out:
# (320, 30, 5)
# (320,)

# %%
plt.figure(figsize=(10, 6))
helper.series.plot_series(time_test, x_test)
helper.series.plot_series(time_test[31:-14], rnn_forecast)
helper.series.plot_series(time_test[31:-14], x_test[31:-14] - rnn_forecast)

# %%
keras.metrics.mean_absolute_error(x_test[31:-14], rnn_forecast).numpy()
# Out:
# 20.75678
